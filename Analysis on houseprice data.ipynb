# %% [markdown]
# # Analysis on House Price Data

# %%
# import numpy
import numpy as np

# import pandas
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# import the dataset
df_house_price_data = pd.read_csv("C:\\Users\\ADMIN\\Downloads\\House_Price.csv")

# %%
# show first 5 observations of the dataset
df_house_price_data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
# show last 5 observations of the dataset
df_house_price_data.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %% [markdown]
# # (1) Data Overview

# %%
# Show the attributes names
df_house_price_data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %% [markdown]
# **Column Info**
#  - `price`: price of the house.
#  - `crime_rate` : crime rate in that area

# %% [markdown]
# ## Basic Statistics (Descriptive Statistics)

# %%
# Shape of the data
# Basic Info
# Basic Description

# %%
# Shape of the data
df_house_price_data.shape
# Out:
# (506, 19)

# %% [markdown]
# **Interpretation**
#  - We have 506 observations and 19 attributes

# %%
# Basic Info 
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# **Interpretation**
#  - We have 16 numerical attributes. It includes 15 floats and 1 integer in nature.
#  - We have 3 catagorical attributes.
#  - In the data we have valid null values.

# %%
# Basic Description
df_house_price_data.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   3.613524   8.601545   0.006320   0.082045   0.256510
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# ...

# %% [markdown]
# **Interpretation**
#  - We have outliers in `crime_rate`,`resid_area`,`age`,`poor_prop`,`n_hot_rooms`

# %% [markdown]
# # 2 Data Preprocessing

# %%
# Data Cleaning
# Null value handling
# Outlier treatment

# %% [markdown]
# ### Data cleaning

# %%
df_house_price_data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %%
# Let's rename the columns 
df_house_price_data = df_house_price_data.rename(columns = {'price':'Price','crime_rate':'Crime_Rate','resid_area':'Resid_Area', 'air_qual':'Air_Quality', 'room_num':'Room_Number', 'age':'Age',
       'dist1':'Distance1', 'dist2':'Distance2', 'dist3':'Distance3', 'dist4':'Distance4', 'teachers':'Teachers', 'poor_prop':'Poor_Prop', 'airport':'Airport',
       'n_hos_beds':'Number_hos_beds', 'n_hot_rooms':'N_Hotel_Room', 'waterbody':'Waterbody', 'rainfall':'Rainfall', 'bus_ter':'Bus_Terminal',
       'parks':'Parks'})
print(df_house_price_data.head())
# Out:
#    Price  Crime_Rate  Resid_Area  Air_Quality  Room_Number   Age  Distance1  \
# 0   24.0     0.00632       32.31        0.538        6.575  65.2       4.35
# 1   21.6     0.02731       37.07        0.469        6.421  78.9       4.99
# 2   34.7     0.02729       37.07        0.469        7.185  61.1       5.03
# 3   33.4     0.03237       32.18        0.458        6.998  45.8       6.21
# 4   36.2     0.06905       32.18        0.458        7.147  54.2       6.16
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop Airport  \
# 0       3.81       4.18       4.01      24.7       4.98     YES
# 1       4.70       5.12       5.06      22.2       9.14      NO
# 2       4.86       5.01       4.97      22.2       4.03      NO
# 3       5.93       6.16       5.96      21.3       2.94     YES
# 4       5.86       6.37       5.86      21.3       5.33      NO
#
#    Number_hos_beds  N_Hotel_Room Waterbody  Rainfall Bus_Terminal     Parks
# ...

# %%
# Lets do the Typecasting here
# Room_Number
# Age
# Teacher
# Number_hos_beds
# N_Hotel_Room

# %%
df_house_price_data['Room_Number'] = df_house_price_data['Room_Number'].astype('int')

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Price            506 non-null    float64
#  1   Crime_Rate       506 non-null    float64
#  2   Resid_Area       506 non-null    float64
#  3   Air_Quality      506 non-null    float64
#  4   Room_Number      506 non-null    int32
#  5   Age              506 non-null    float64
#  6   Distance1        506 non-null    float64
#  7   Distance2        506 non-null    float64
#  8   Distance3        506 non-null    float64
#  9   Distance4        506 non-null    float64
#  10  Teachers         506 non-null    float64
#  11  Poor_Prop        506 non-null    float64
#  12  Airport          506 non-null    object
#  13  Number_hos_beds  498 non-null    float64
#  14  N_Hotel_Room     506 non-null    float64
#  15  Waterbody        506 non-null    object
# ...

# %%
df_house_price_data['Age'] = df_house_price_data['Age'].astype('int')

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Price            506 non-null    float64
#  1   Crime_Rate       506 non-null    float64
#  2   Resid_Area       506 non-null    float64
#  3   Air_Quality      506 non-null    float64
#  4   Room_Number      506 non-null    int32
#  5   Age              506 non-null    int32
#  6   Distance1        506 non-null    float64
#  7   Distance2        506 non-null    float64
#  8   Distance3        506 non-null    float64
#  9   Distance4        506 non-null    float64
#  10  Teachers         506 non-null    float64
#  11  Poor_Prop        506 non-null    float64
#  12  Airport          506 non-null    object
#  13  Number_hos_beds  498 non-null    float64
#  14  N_Hotel_Room     506 non-null    float64
#  15  Waterbody        506 non-null    object
# ...

# %% [raw]
# df_house_price_data['Number_hos_beds'] = df_house_price_data['Number_hos_beds'].astype('int')

# %%
df_house_price_data['N_Hotel_Room'] = df_house_price_data['N_Hotel_Room'].astype('int')
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Price            506 non-null    float64
#  1   Crime_Rate       506 non-null    float64
#  2   Resid_Area       506 non-null    float64
#  3   Air_Quality      506 non-null    float64
#  4   Room_Number      506 non-null    int32
#  5   Age              506 non-null    int32
#  6   Distance1        506 non-null    float64
#  7   Distance2        506 non-null    float64
#  8   Distance3        506 non-null    float64
#  9   Distance4        506 non-null    float64
#  10  Teachers         506 non-null    float64
#  11  Poor_Prop        506 non-null    float64
#  12  Airport          506 non-null    object
#  13  Number_hos_beds  498 non-null    float64
#  14  N_Hotel_Room     506 non-null    int32
#  15  Waterbody        506 non-null    object
# ...

# %%
# In previous we did the type casting based on observations and domain expertise 
# Now the time is for the data visualization
df_house_price_data.hist()
plt.tight_layout()
plt.show()

# %%
df_house_price_data.N_Hotel_Room.plot(kind = 'kde')
plt.show()

# %%
df_house_price_data.Room_Number.plot(kind = 'kde')
plt.show()

# %%
df_house_price_data.Price.plot(kind = 'kde')
plt.show()

# %%
# Room_Number
# N_Hotel_Room
df_house_price_data.Room_Number.hist(color = 'yellow')
plt.show()

# %%
df_house_price_data.N_Hotel_Room.hist(color = 'black')
plt.show()

# %%
df_house_price_data.N_Hotel_Room.plot(kind = 'kde')
plt.show()

# %%
df_house_price_data['Room_Number'] = df_house_price_data['Room_Number'].astype('object')
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Price            506 non-null    float64
#  1   Crime_Rate       506 non-null    float64
#  2   Resid_Area       506 non-null    float64
#  3   Air_Quality      506 non-null    float64
#  4   Room_Number      506 non-null    object
#  5   Age              506 non-null    int32
#  6   Distance1        506 non-null    float64
#  7   Distance2        506 non-null    float64
#  8   Distance3        506 non-null    float64
#  9   Distance4        506 non-null    float64
#  10  Teachers         506 non-null    float64
#  11  Poor_Prop        506 non-null    float64
#  12  Airport          506 non-null    object
#  13  Number_hos_beds  498 non-null    float64
#  14  N_Hotel_Room     506 non-null    int32
#  15  Waterbody        506 non-null    object
# ...

# %% [markdown]
# ### Null value handling

# %%
df_house_price_data.head()
# Out:
#    Price  Crime_Rate  Resid_Area  Air_Quality Room_Number  Age  Distance1  \
# 0   24.0     0.00632       32.31        0.538           6   65       4.35
# 1   21.6     0.02731       37.07        0.469           6   78       4.99
# 2   34.7     0.02729       37.07        0.469           7   61       5.03
# 3   33.4     0.03237       32.18        0.458           6   45       6.21
# 4   36.2     0.06905       32.18        0.458           7   54       6.16
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop Airport  \
# 0       3.81       4.18       4.01      24.7       4.98     YES
# 1       4.70       5.12       5.06      22.2       9.14      NO
# 2       4.86       5.01       4.97      22.2       4.03      NO
# 3       5.93       6.16       5.96      21.3       2.94     YES
# 4       5.86       6.37       5.86      21.3       5.33      NO
#
#    Number_hos_beds  N_Hotel_Room Waterbody  Rainfall Bus_Terminal     Parks
# ...

# %%
# Find the number of missing values
df_house_price_data.isnull().sum()
# Out:
# Price              0
# Crime_Rate         0
# Resid_Area         0
# Air_Quality        0
# Room_Number        0
# Age                0
# Distance1          0
# Distance2          0
# Distance3          0
# Distance4          0
# Teachers           0
# Poor_Prop          0
# Airport            0
# Number_hos_beds    8
# N_Hotel_Room       0
# Waterbody          0
# Rainfall           0
# Bus_Terminal       0
# Parks              0
# dtype: int64

# %%
df_house_price_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Price            506 non-null    float64
#  1   Crime_Rate       506 non-null    float64
#  2   Resid_Area       506 non-null    float64
#  3   Air_Quality      506 non-null    float64
#  4   Room_Number      506 non-null    object
#  5   Age              506 non-null    int32
#  6   Distance1        506 non-null    float64
#  7   Distance2        506 non-null    float64
#  8   Distance3        506 non-null    float64
#  9   Distance4        506 non-null    float64
#  10  Teachers         506 non-null    float64
#  11  Poor_Prop        506 non-null    float64
#  12  Airport          506 non-null    object
#  13  Number_hos_beds  498 non-null    float64
#  14  N_Hotel_Room     506 non-null    int32
#  15  Waterbody        506 non-null    object
# ...

# %%
# Laws 
# When we have less then 10% data is misssing remove the observations
# When we have missing % between 30-70% then we need to impute the missing values
# When we have more than 80% data is missing , remove the attribute

# %%
round(df_house_price_data.isnull().sum()/len(df_house_price_data)*100,2)
# Out:
# Price              0.00
# Crime_Rate         0.00
# Resid_Area         0.00
# Air_Quality        0.00
# Room_Number        0.00
# Age                0.00
# Distance1          0.00
# Distance2          0.00
# Distance3          0.00
# Distance4          0.00
# Teachers           0.00
# Poor_Prop          0.00
# Airport            0.00
# Number_hos_beds    1.58
# N_Hotel_Room       0.00
# Waterbody          0.00
# Rainfall           0.00
# Bus_Terminal       0.00
# Parks              0.00
# dtype: float64

# %%
# We have less than 2 % Replace the null values in Number_hos_beds 
df_house_price_data.dropna(inplace=True)
df_house_price_data.isnull().sum()
# Out:
# Price              0
# Crime_Rate         0
# Resid_Area         0
# Air_Quality        0
# Room_Number        0
# Age                0
# Distance1          0
# Distance2          0
# Distance3          0
# Distance4          0
# Teachers           0
# Poor_Prop          0
# Airport            0
# Number_hos_beds    0
# N_Hotel_Room       0
# Waterbody          0
# Rainfall           0
# Bus_Terminal       0
# Parks              0
# dtype: int64

# %% [markdown]
# ## Outlier Detection and Treatment

# %%
df_house_price_data.plot(kind = 'box')
plt.xticks(rotation=90)
plt.title('Outlier Detection')
plt.show()

# %%
df_num = df_house_price_data.select_dtypes(np.number)

# %%
# We can set the outlier by mean , by extend the upper and lower bound , the third option will be delete but it cant be applicable

# %%
q1 = df_num.quantile(0.25)
q3 = df_num.quantile(0.75)
iqr = q3 - q1
df_num = df_num[(df_num>= q1 - 1.5*iqr) & (df_num <= q3 + 1.5*iqr)]

# %%
df_num = df_num.reset_index()

# %%
df_num.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
# concate the treated dataframe with categorical dataframe
df_Cat = df_house_price_data.select_dtypes('object')

# %%
df_Cat = df_Cat.reset_index()

# %%
print(df_num.shape)
print(df_Cat.shape)
# Out:
# (498, 16)
# (498, 5)

# %%
# concate both 
df_house_price_data = pd.concat((df_num,df_Cat),axis = 1)
df_house_price_data.shape
# Out:
# (498, 21)

# %%
df_house_price_data.isnull().sum()
# Out:
# index               0
# Price              39
# Crime_Rate         64
# Resid_Area          0
# Air_Quality         0
# Age                 0
# Distance1           5
# Distance2           5
# Distance3           5
# Distance4           5
# Teachers           14
# Poor_Prop           7
# Number_hos_beds     0
# N_Hotel_Room        2
# Rainfall            0
# Parks               5
# index               0
# Room_Number         0
# Airport             0
# Waterbody           0
# Bus_Terminal        0
# dtype: int64

# %%
df_house_price_data.dropna(inplace=True)

# %%
df_house_price_data.isnull().sum()
# Out:
# index              0
# Price              0
# Crime_Rate         0
# Resid_Area         0
# Air_Quality        0
# Age                0
# Distance1          0
# Distance2          0
# Distance3          0
# Distance4          0
# Teachers           0
# Poor_Prop          0
# Number_hos_beds    0
# N_Hotel_Room       0
# Rainfall           0
# Parks              0
# index              0
# Room_Number        0
# Airport            0
# Waterbody          0
# Bus_Terminal       0
# dtype: int64

# %% [markdown]
# ### 3 EDA

# %%
# Univariate Analysis
# Bivariate Analysis
# Multivariate Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
# Let's saggregate the numerical columns and the catagorical columns
df_num = df_house_price_data.select_dtypes(include = np.number)

# %%
df_num.head()
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
# 3      3   33.4     0.03237       32.18        0.458   45       6.21
# 4      4   36.2     0.06905       32.18        0.458   54       6.16
# 5      5   28.7     0.02985       32.18        0.458   58       6.22
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
# 3       5.93       6.16       5.96      21.3       2.94            9.268
# 4       5.86       6.37       5.86      21.3       5.33            8.824
# 5       5.80       6.23       5.99      21.3       5.21            7.174
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# ...

# %%
# Catagorical dataframe
df_cat = df_house_price_data.select_dtypes(include = ['object'])
df_cat.head()
# Out:
#   Room_Number Airport Waterbody Bus_Terminal
# 0           6     YES     River          YES
# 1           6      NO      Lake          YES
# 3           6     YES      Lake          YES
# 4           7      NO      Lake          YES
# 5           6     YES      None          YES

# %% [markdown]
# #### Room Number

# %%
# Find the count of each catagory in that particular column
df_cat.Room_Number.value_counts()
# Out:
# 6    228
# 5    120
# 7     22
# 4      4
# 8      1
# 3      1
# Name: Room_Number, dtype: int64

# %%
# Visualize the count
df_cat.Room_Number.value_counts().plot(kind = 'bar' , color = 'yellow')

plt.xlabel('Room_Number')
plt.show()

# %% [markdown]
# **Interpretation**
#  - We have imbalance data in Room Number Column
#  - 6 is a catagory who is dominating the most , It's count is 266.
#  - 3 is the catagory having least number of observation, It's count is 2.

# %%
df_cat.head()
# Out:
#   Room_Number Airport Waterbody Bus_Terminal
# 0           6     YES     River          YES
# 1           6      NO      Lake          YES
# 3           6     YES      Lake          YES
# 4           7      NO      Lake          YES
# 5           6     YES      None          YES

# %% [markdown]
# #### Airports

# %%
# Find the value count for Airport
df_cat.Airport.value_counts()
# Out:
# YES    205
# NO     171
# Name: Airport, dtype: int64

# %%
df_cat.Airport.value_counts().plot(kind = 'bar' , color = 'yellow')
plt.xlabel('Airports')
plt.show()

# %% [markdown]
# **Interpretation**
#  - We havew balanced data in the Airports column
#  - There are 273 places where airport is present and 225 places have no airports

# %%
df_cat.head(2)
# Out:
#   Room_Number Airport Waterbody Bus_Terminal
# 0           6     YES     River          YES
# 1           6      NO      Lake          YES

# %% [markdown]
# #### Waterbody

# %%
# Find the value count for Waterbody
df_cat.Waterbody.value_counts()
# Out:
# River             139
# None              112
# Lake               70
# Lake and River     55
# Name: Waterbody, dtype: int64

# %%
df_cat.Waterbody.value_counts().plot(kind = 'bar' , color = 'blue')
plt.title('Count of Waterbody')
plt.ylabel('Count')
plt.xlabel('Waterbody')
plt.xticks(rotation = 45)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - Most of the places having the river and waterbody and count is 178
#  - There is few places where lake and river are the waterbody
#  - This data is also imbalanced

# %%
df_cat.head(2)
# Out:
#   Room_Number Airport Waterbody Bus_Terminal
# 0           6     YES     River          YES
# 1           6      NO      Lake          YES

# %% [markdown]
# #### Bus_Terminal

# %%
# Find the value count for Bus_Terminal
df_cat.Bus_Terminal.value_counts()
# Out:
# YES    376
# Name: Bus_Terminal, dtype: int64

# %%
df_cat.Bus_Terminal.value_counts().plot(kind = 'bar' , color = 'yellow')
plt.title('Count of Bus_Terminal')
plt.ylabel('Count')
plt.xlabel('Availabe Bus_Terminal')
plt.show()

# %% [markdown]
# **Interpretation**
#  - All the places we have , contains the bus terminal.
#  - ACTION:Remove that column from the data

# %%
# Drop the columns
df_house_price_data.drop('Bus_Terminal',axis= 1 ,inplace = True)

# %%
df_house_price_data.shape
# Out:
# (376, 20)

# %%
df_house_price_data.shape[0]
# Out:
# 376

# %%
df_house_price_data.shape[1]
# Out:
# 20

# %% [markdown]
# ## Univariate analysis on numerical data

# %%
df_num.head()
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
# 3      3   33.4     0.03237       32.18        0.458   45       6.21
# 4      4   36.2     0.06905       32.18        0.458   54       6.16
# 5      5   28.7     0.02985       32.18        0.458   58       6.22
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
# 3       5.93       6.16       5.96      21.3       2.94            9.268
# 4       5.86       6.37       5.86      21.3       5.33            8.824
# 5       5.80       6.23       5.99      21.3       5.21            7.174
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# ...

# %% [markdown]
# #### Price

# %%
df_num.Price.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Price')
plt.xlabel('Price')
plt.grid()
plt.show()

# %%
# Find the minimum value
df_num.Price.min()
# Out:
# 7.0

# %%
# Find the maximum value
df_num.Price.max()
# Out:
# 36.4

# %%
# Find the Average value
df_num.Price.mean()
# Out:
# 21.84680851063831

# %% [markdown]
# **Interpretation**
#  - This data is slightly normally distributed
#  - The houses we have their prices lies between 8 lakhs to 40 lakhs
#  - The house we have with least price is 5 lakhs
#  - The house with maximum price is 50 lakhs
#  - The house with average price is 22.57 lakhs

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Crime_Rate

# %%
# Find the minimum value
df_num.Crime_Rate.min()
# Out:
# 0.00632

# %%
# Find the maximum value
df_num.Crime_Rate.max()
# Out:
# 8.98296

# %%
# Find the Average value
df_num.Crime_Rate.mean()
# Out:
# 1.2156331382978725

# %%
df_num.Crime_Rate.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Crime_Rate')
plt.xlabel('Crime_Rate')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is not normally distributed
#  - The crime rate is lies between 0.006 to 20
#  - The maximum crime rate is 88.976
#  - The minimum crime rate is 0.006
#  - The average crime rate is 3.588

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Resid_Area

# %%
# Find the minimum value
df_num.Resid_Area.min()
# Out:
# 30.74

# %%
# Find the maximum value
df_num.Resid_Area.max()
# Out:
# 57.74

# %%
# Find the Average value
df_num.Resid_Area.mean()
# Out:
# 40.44361702127665

# %%
df_num.Resid_Area.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Resid_Area')
plt.xlabel('Resid_Area')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - This data is multimodel
#  - The first interpretation is lies between 28 to 42 for first model and 43 to 55 for another model
#  - It is not normally distributed
#  - The maximum Resid_Area is 57.74
#  - The minimum Resid_Area is 30.46
#  - The average Resid_Area is 41.12

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Air_Quality

# %%
# Find the minimum value
df_num.Air_Quality.min()
# Out:
# 0.385

# %%
# Find the maximum value
df_num.Air_Quality.max()
# Out:
# 0.871

# %%
# Find the Average value
df_num.Air_Quality.mean()
# Out:
# 0.5334140957446819

# %%
df_num.Air_Quality.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Air_Quality')
plt.xlabel('Air_Quality')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - It is not normally distributed
#  - The maximum Air_Quality is 0.871
#  - The minimum Air_Quality is 0.385
#  - The average Air_Quality is 0.553

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Age

# %%
# Find the minimum value
df_num.Age.min()
# Out:
# 2

# %%
# Find the maximum value
df_num.Age.max()
# Out:
# 100

# %%
# Find the Average value
df_num.Age.mean()
# Out:
# 63.922872340425535

# %%
df_num.Age.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Age')
plt.xlabel('Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - This data is multimodel
#  - The first interpretation is lies between 0 to 75 for first model and 76 to 124 for another model
#  - It is not normally distributed
#  - The maximum Age is 100
#  - The minimum Age is 2
#  - The average Age is 68.048

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Distance1

# %%
# Find the minimum value
df_num.Distance1.min()
# Out:
# 1.34

# %%
# Find the maximum value
df_num.Distance1.max()
# Out:
# 9.44

# %%
# Find the Average value
df_num.Distance1.mean()
# Out:
# 4.317952127659573

# %%
df_num.Distance1.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Distance1')
plt.xlabel('Distance1')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The interpretation is lies between 2 to 13
#  - It is not normally distributed
#  - The maximum Distance1 is 12.32
#  - The minimum Distance1 is 1.13
#  - The average Distance1 is 3.985

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Distance2

# %%
# Find the minimum value
df_num.Distance2.min()
# Out:
# 1.04

# %%
# Find the maximum value
df_num.Distance2.max()
# Out:
# 9.11

# %%
# Find the Average value
df_num.Distance2.mean()
# Out:
# 3.9738297872340413

# %%
df_num.Distance2.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Distance2')
plt.xlabel('Distance2')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The interpretation is lies between 2 to 13
#  - It is not normally distributed
#  - The maximum Distance2 is 11.93
#  - The minimum Distance2 is 0.92
#  - The average Distance2 is 3.64

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %%
# Find the minimum value
df_num.Distance3.min()
# Out:
# 1.55

# %%
# Find the maximum value
df_num.Distance3.max()
# Out:
# 9.48

# %%
# Find the Average value
df_num.Distance3.mean()
# Out:
# 4.309601063829786

# %%
df_num.Distance3.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Distance3')
plt.xlabel('Distance3')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The interpretation is lies between 2 to 13
#  - It is not normally distributed
#  - The maximum Distance2 is 12.32
#  - The minimum Distance2 is 1.15
#  - The average Distance2 is 3.97

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Teachers

# %%
# Find the minimum value
df_num.Teachers.min()
# Out:
# 18.8

# %%
# Find the maximum value
df_num.Teachers.max()
# Out:
# 25.3

# %%
# Find the Average value
df_num.Teachers.mean()
# Out:
# 21.471808510638347

# %%
df_num.Teachers.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Teachers')
plt.xlabel('Teachers')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - It is multimodes
#  - The interpretation is lies between 17.7 to 27.
#  - It is not normally distributed
#  - The maximum Teachers is 27
#  - The minimum Teachers is 18
#  - The average Teachers is 21

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Poor_Prop

# %%
# Find the minimum value
df_num.Poor_Prop.min()
# Out:
# 1.98

# %%
# Find the maximum value
df_num.Poor_Prop.max()
# Out:
# 30.81

# %%
# Find the Average value
df_num.Poor_Prop.mean()
# Out:
# 11.77497340425532

# %%
df_num.Poor_Prop.plot(kind = 'kde', color='blue')
plt.title('KDE plot on Poor_Prop')
plt.xlabel('Poor_Prop')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The interpretation is lies between 0 to 35.
#  - It is not normally distributed
#  - The maximum Poor_Prop is 37.97
#  - The minimum Poor_Prop is 1.73
#  - The average Poor_Prop is 12.59

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### N_Hotel_beds

# %%
# Find the minimum value
df_num.N_Hotel_Room.min()
# Out:
# 10.0

# %%
# Find the maximum value
df_num.N_Hotel_Room.max()
# Out:
# 15.0

# %%
# Find the Average value
df_num.N_Hotel_Room.mean()
# Out:
# 12.5

# %%
df_num.N_Hotel_Room.plot(kind = 'kde', color='blue')
plt.title('N_Hotel_Room')
plt.xlabel('N_Hotel_Room')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The interpretation is lies between 2 to 24.
#  - It is not normally distributed
#  - The maximum N_Hotel_Room is 101
#  - The minimum N_Hotel_Room is 10
#  - The average N_Hotel_Room is 12.86

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Number_hos_beds

# %%
# Find the minimum value
df_num.Number_hos_beds.min()
# Out:
# 5.268

# %%
# Find the maximum value
df_num.Number_hos_beds.max()
# Out:
# 10.668

# %%
# Find the Average value
df_num.Number_hos_beds.mean()
# Out:
# 7.876297872340428

# %%
df_num.Number_hos_beds.plot(kind = 'kde', color='blue')
plt.title('Number_hos_beds')
plt.xlabel('Number_hos_beds')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#
#  - The interpretation is lies between 4 to 12.
#  - It is not normally distributed
#  - The maximum N_Hotel_Room is 5.268
#  - The minimum N_Hotel_Room is 10.668
#  - The average N_Hotel_Room is 7.876297872340428

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Rainfall

# %%
# Find the minimum value
df_num.Rainfall.min()
# Out:
# 3

# %%
# Find the maximum value
df_num.Rainfall.max()
# Out:
# 60

# %%
# Find the average value
df_num.Rainfall.mean()
# Out:
# 38.598404255319146

# %%
df_num.Rainfall.plot(kind = 'kde', color='blue')
plt.title('Rainfall')
plt.xlabel('Rainfall')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#
#  - The interpretation is lies between 10 to 70.
#  - It is not normally distributed
#  - The maximum Rainfall is 3
#  - The minimum Rainfall is 60
#  - The average Rainfall is 38.598404255319146

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Parks

# %%
# Find the minimum value
df_num.Parks.min()
# Out:
# 0.033291762

# %%
# Find the maximum value
df_num.Parks.max()
# Out:
# 0.083032787

# %%
# Find the average value
df_num.Parks.mean()
# Out:
# 0.05268840343882978

# %%
df_num.Parks.plot(kind = 'kde', color='green')
plt.title('Parks')
plt.xlabel('Parks')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#
#  - The interpretation is lies between 0.03 to 0.09.
#  - It is slightly normally distributed
#  - The maximum Parks is 0.033291762
#  - The minimum Parks is 0.083032787
#  - The average Parks is 0.05268840343882978

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Quality  Age  Distance1  \
# 0      0   24.0     0.00632       32.31        0.538   65       4.35
# 1      1   21.6     0.02731       37.07        0.469   78       4.99
#
#    Distance2  Distance3  Distance4  Teachers  Poor_Prop  Number_hos_beds  \
# 0       3.81       4.18       4.01      24.7       4.98            5.480
# 1       4.70       5.12       5.06      22.2       9.14            7.332
#
#    N_Hotel_Room  Rainfall     Parks  index
# 0          11.0        23  0.049347      0
# 1          12.0        42  0.046146      1

# %% [markdown]
# #### Bivariate Analysis

# %%
# step1 : Do the bivariate analysis for numerical variates
# Find the corelation
df_house_price_data.corr()
# Out:
#                     index     Price  Crime_Rate  Resid_Area  Air_Quality  \
# index            1.000000 -0.130497    0.521741    0.326491     0.322834
# Price           -0.130497  1.000000   -0.424735   -0.539404    -0.518091
# Crime_Rate       0.521741 -0.424735    1.000000    0.554473     0.649419
# Resid_Area       0.326491 -0.539404    0.554473    1.000000     0.753000
# Air_Quality      0.322834 -0.518091    0.649419    0.753000     1.000000
# Age              0.081943 -0.556358    0.418289    0.598148     0.688243
# Distance1       -0.228977  0.368112   -0.456078   -0.700206    -0.745603
# Distance2       -0.233908  0.365491   -0.455079   -0.703032    -0.747011
# Distance3       -0.236092  0.364496   -0.458358   -0.703908    -0.746911
# Distance4       -0.220572  0.366804   -0.447356   -0.702769    -0.742947
# Teachers        -0.200740  0.398508   -0.302125   -0.289787    -0.189400
# Poor_Prop        0.074148 -0.750503    0.393205    0.562430     0.539936
# ...

# %%
# draw the heatmap for corelation
sns.heatmap(df_num.corr(),annot=True)
sns.set(rc={"figure.figsize":(20,300)})

# %%
# Parks - Crime_Rate
# Parks - Resid_Area
# Parks - Air_Quality
# Parks - Age
# Parks - Distance1
# Parks - Distance2
# Parks - Distance3
# Parks - Distance4
# Parks - Poor_Prop
# Poor_Prop - Price
# Poor_Prop - Age
# Poor_Prop - Resid_Area
# Poor_Prop - Air_Quality
# Distance4 - Resid_Area
# Distance4 - Air_Quality
# Distance4 - Age
# Distance4 - Distance3
# Distance4 - Distance2
# Distance4 - Distance1
# Distance3 - Resid_Area
# Distance3 - Air_Quality
# Distance3 - Age
# Distance3 - Distance2
# Distance3 - Distance1
# Distance2 - Resid_Area
# Distance2 - Air_Quality
# Distance2 - Age
# Distance2 - Distance1
# Distance1 - Resid_Area
# Distance1 - Air_Quality
# Distance1 - Age
# Age - Price
# Age - Resid_Area
# Age - Air_Quality
# Air_Quality - Price
# Air_Quality - Crime_Rate
# Air_Quality - Resid_Area
# Resid_Area - Price
# Resid_Area - Crime_Rate

# %% [markdown]
# #### Parks - Crime_Rate

# %%
sns.scatterplot(x='Parks', y='Crime_Rate', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Crime_Rate')
plt.title('Corelation between Parks and Crime_Rate', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Parks - Resid_Area

# %%
sns.scatterplot(x='Parks', y='Resid_Area', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Resid_Area')
plt.title('Corelation between Parks and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Parks - Air_Quality

# %%
sns.scatterplot(x='Parks', y='Air_Quality', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Air_Quality')
plt.title('Corelation between Parks and Air_Quality', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Parks - Age

# %%
sns.scatterplot(x='Parks', y='Age', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Age')
plt.title('Corelation between Parks and Age', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Parks - Distance1

# %%
sns.scatterplot(x='Parks', y='Distance1', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Distance1')
plt.title('Corelation between Parks and Distance1', fontsize= 15 )
plt.show()

# %%
sns.pairplot(data = df_num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [148], in <cell line: 1>()
# ----> 1 sns.pairplot(data = df_num)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2096, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094 # Set up the PairGrid
# ...

# %% [markdown]
# #### Parks - Distance2

# %%
sns.scatterplot(x='Parks', y='Distance2', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Distance2')
plt.title('Corelation between Parks and Distance2', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Parks - Distance3

# %%
sns.scatterplot(x='Parks', y='Distance3', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Distance3')
plt.title('Corelation between Parks and Distance3', fontsize= 15 )
plt.show()

# %% [markdown]
# # Parks - Distance4

# %%
sns.scatterplot(x='Parks', y='Distance4', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Distance4')
plt.title('Corelation between Parks and Distance4', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Parks - Poor_Prop

# %%
sns.scatterplot(x='Parks', y='Poor_Prop', data = df_num)
plt.xlabel('Parks')
plt.ylabel('Poor_Prop')
plt.title('Corelation between Parks and Poor_Prop', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Poor_Prop - Price

# %%
sns.scatterplot(x='Poor_Prop', y='Price', data = df_num)
plt.xlabel('Poor_Prop')
plt.ylabel('Price')
plt.title('Corelation between Poor_Prop and Price', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Poor_Prop - Age

# %%
sns.scatterplot(x='Poor_Prop', y='Age', data = df_num)
plt.xlabel('Poor_Prop')
plt.ylabel('Age')
plt.title('Corelation between Poor_Prop and Age', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Poor_Prop - Resid_Area

# %%
sns.scatterplot(x='Poor_Prop', y='Resid_Area', data = df_num)
plt.xlabel('Poor_Prop')
plt.ylabel('Resid_Area')
plt.title('Corelation between Poor_Prop and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Poor_Prop - Air_Quality

# %%
sns.scatterplot(x='Poor_Prop', y='Air_Quality', data = df_num)
plt.xlabel('Poor_Prop')
plt.ylabel('Air_Quality')
plt.title('Corelation between Poor_Prop and Air_Quality', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance4 - Resid_Area

# %%
sns.scatterplot(x='Distance4', y='Resid_Area', data = df_num)
plt.xlabel('Distance4')
plt.ylabel('Resid_Area')
plt.title('Corelation between Distance4 and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance4 - Air_Quality

# %%
sns.scatterplot(x='Distance4', y='Air_Quality', data = df_num)
plt.xlabel('Distance4')
plt.ylabel('Air_Quality')
plt.title('Corelation between Distance4 and Air_Quality', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance4 - Age

# %%
sns.scatterplot(x='Distance4', y='Age', data = df_num)
plt.xlabel('Distance4')
plt.ylabel('Age')
plt.title('Corelation between Distance4 and Age', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance4 - Distance3

# %%
sns.scatterplot(x='Distance4', y='Distance3', data = df_num)
plt.xlabel('Distance4')
plt.ylabel('Distance3')
plt.title('Corelation between Distance4 and Distance3', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance4 - Distance2

# %%
sns.scatterplot(x='Distance4', y='Distance2', data = df_num)
plt.xlabel('Distance4')
plt.ylabel('Distance2')
plt.title('Corelation between Distance4 and Distance2', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance4 - Distance1

# %%
sns.scatterplot(x='Distance4', y='Distance1', data = df_num)
plt.xlabel('Distance4')
plt.ylabel('Distance1')
plt.title('Corelation between Distance4 and Distance1', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance3 - Resid_Area

# %%
sns.scatterplot(x='Distance3', y='Resid_Area', data = df_num)
plt.xlabel('Distance3')
plt.ylabel('Resid_Area')
plt.title('Corelation between Distance3 and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance3 - Air_Quality

# %%
sns.scatterplot(x='Distance3', y='Air_Quality', data = df_num)
plt.xlabel('Distance3')
plt.ylabel('Air_Quality')
plt.title('Corelation between Distance3 and Air_Quality', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance3 - Age

# %%
sns.scatterplot(x='Distance3', y='Age', data = df_num)
plt.xlabel('Distance3')
plt.ylabel('Age')
plt.title('Corelation between Distance3 and Age', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance3 - Distance2

# %%
sns.scatterplot(x='Distance3', y='Distance2', data = df_num)
plt.xlabel('Distance3')
plt.ylabel('Distance2')
plt.title('Corelation between Distance3 and Distance2', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance3 - Distance1

# %%
sns.scatterplot(x='Distance3', y='Distance1', data = df_num)
plt.xlabel('Distance3')
plt.ylabel('Distance1')
plt.title('Corelation between Distance3 and Distance1', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance2 - Resid_Area

# %%
sns.scatterplot(x='Distance2', y='Resid_Area', data = df_num)
plt.xlabel('Distance2')
plt.ylabel('Resid_Area')
plt.title('Corelation between Distance2 and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance2 - Air_Quality

# %%
sns.scatterplot(x='Distance2', y='Air_Quality', data = df_num)
plt.xlabel('Distance2')
plt.ylabel('Air_Quality')
plt.title('Corelation between Distance2 and Air_Quality', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance2 - Age

# %%
sns.scatterplot(x='Distance2', y='Age', data = df_num)
plt.xlabel('Distance2')
plt.ylabel('Age')
plt.title('Corelation between Distance2 and Age', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance2 - Distance1

# %%
sns.scatterplot(x='Distance2', y='Distance1', data = df_num)
plt.xlabel('Distance2')
plt.ylabel('Distance1')
plt.title('Corelation between Distance2 and Distance1', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance1 - Resid_Area

# %%
sns.scatterplot(x='Distance1', y='Resid_Area', data = df_num)
plt.xlabel('Distance1')
plt.ylabel('Resid_Area')
plt.title('Corelation between Distance1 and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance1 - Air_Quality

# %%
sns.scatterplot(x='Distance1', y='Air_Quality', data = df_num)
plt.xlabel('Distance1')
plt.ylabel('Air_Quality')
plt.title('Corelation between Distance1 and Air_Quality', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Distance1 - Age

# %%
sns.scatterplot(x='Distance1', y='Age', data = df_num)
plt.xlabel('Distance1')
plt.ylabel('Age')
plt.title('Corelation between Distance1 and Age', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Age - Price

# %%
sns.scatterplot(x='Age', y='Price', data = df_num)
plt.xlabel('Age')
plt.ylabel('Price')
plt.title('Corelation between Age and Price', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Age - Resid_Area

# %%
sns.scatterplot(x='Age', y='Resid_Area', data = df_num)
plt.xlabel('Age')
plt.ylabel('Resid_Area')
plt.title('Corelation between Age and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Age - Air_Quality

# %%
sns.scatterplot(x='Age', y='Air_Quality', data = df_num)
plt.xlabel('Age')
plt.ylabel('Air_Quality')
plt.title('Corelation between Age and Air_Quality', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Air_Quality - Price

# %%
sns.scatterplot(x='Air_Quality', y='Price', data = df_num)
plt.xlabel('Air_Quality')
plt.ylabel('Price')
plt.title('Corelation between Air_Quality and Price', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Air_Quality - Crime_Rate

# %%
sns.scatterplot(x='Air_Quality', y='Crime_Rate', data = df_num)
plt.xlabel('Air_Quality')
plt.ylabel('Crime_Rate')
plt.title('Corelation between Air_Quality and Crime_Rate', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Air_Quality - Resid_Area

# %%
sns.scatterplot(x='Air_Quality', y='Resid_Area', data = df_num)
plt.xlabel('Air_Quality')
plt.ylabel('Resid_Area')
plt.title('Corelation between Air_Quality and Resid_Area', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Resid_Area - Price

# %%
sns.scatterplot(x='Resid_Area', y='Price', data = df_num)
plt.xlabel('Resid_Area')
plt.ylabel('Price')
plt.title('Corelation between Resid_Area and Price', fontsize= 15 )
plt.show()

# %% [markdown]
# #### Resid_Area - Crime_Rate

# %%
sns.scatterplot(x='Resid_Area', y='Crime_Rate', data = df_num)
plt.xlabel('Resid_Area')
plt.ylabel('Crime_Rate')
plt.title('Corelation between Resid_Area and Crime_Rate', fontsize= 15 )
plt.show()

# %%
# Parks
# Price
# Poor_Prop
# Air_Quality

# %%
x = 'Room_Number'
y = 'Parks'
plt.bar(x,y,data = df_house_price_data)
sns.set(rc={"figure.figsize":(10,10)})
plt.show()

# %%
df_cat.head()
# Out:
#   Room_Number Airport Waterbody Bus_Terminal
# 0           6     YES     River          YES
# 1           6      NO      Lake          YES
# 3           6     YES      Lake          YES
# 4           7      NO      Lake          YES
# 5           6     YES      None          YES

# %%
df_house_price_data.Room_Number.value_counts()
# Out:
# 6    228
# 5    120
# 7     22
# 4      4
# 8      1
# 3      1
# Name: Room_Number, dtype: int64

# %%
sns.barplot(x = 'Room_Number', y = 'Parks', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Room_Number', ylabel='Parks'>

# %%
sns.barplot(x = 'Room_Number', y = 'Price', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Room_Number', ylabel='Price'>

# %%
sns.barplot(x = 'Room_Number', y = 'Poor_Prop', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Room_Number', ylabel='Poor_Prop'>

# %%
sns.barplot(x = 'Room_Number', y = 'Air_Quality', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Room_Number', ylabel='Air_Quality'>

# %% [markdown]
# **Interpretation**
#  -

# %%
sns.barplot(x = 'Airport', y = 'Parks', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Airport', ylabel='Parks'>

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %%
sns.barplot(x = 'Airport', y = 'Price', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Airport', ylabel='Price'>

# %% [markdown]
# **Interpretation**
#  - Nothing special

# %%
sns.barplot(x = 'Airport', y = 'Poor_Prop', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Airport', ylabel='Poor_Prop'>

# %% [markdown]
# **Interpretation**
#
#  - Nothing special

# %%
sns.barplot(x = 'Airport', y = 'Air_Quality', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Airport', ylabel='Air_Quality'>

# %% [markdown]
# **Interpretation**
#
#  - Nothing special

# %%
sns.barplot(x = 'Waterbody', y = 'Parks', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Waterbody', ylabel='Parks'>

# %% [markdown]
# **Interpretation**
#
#  - Nothing special

# %%
sns.barplot(x = 'Waterbody', y = 'Price', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Waterbody', ylabel='Price'>

# %%
sns.barplot(x = 'Waterbody', y = 'Poor_Prop', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Waterbody', ylabel='Poor_Prop'>

# %% [markdown]
# **Interpretation**
#
#  - Nothing special

# %%
sns.barplot(x = 'Waterbody', y = 'Air_Quality', data = df_house_price_data)
# Out:
# <AxesSubplot:xlabel='Waterbody', ylabel='Air_Quality'>

# %% [markdown]
# **Interpretation**
#
#  - Nothing special

# %% [markdown]
# ## Multivariate Analysis

# %%
# odd huv
# cross tab
# Pivot table
